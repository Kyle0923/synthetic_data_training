    0.7697032786817526,
    0.7725024422531934,
]
AUCs = [
    0.6505860000000001,
    0.454866,
    0.452243,
    0.6228365,
    0.590174,
    0.51,
    0.507,
    0.513,
    0.853947,
    0.848921,
    0.846463,
    0.831955,
    0.834691,
    0.8256039999999999,
    0.7842910000000001,
    0.7105815,
    0.6367299999999999,
    0.542737,
    0.465049,
    0.420227,
    0.392744,
    0.3826505,
    0.390571,
    0.406077,
    0.42794599999999994,
    0.4553865,
    0.48829,
    0.553616,
    0.608036,
    0.682668,
    0.7376805000000001,
    0.7844809999999999,
    0.811484,
    0.8322709999999999,
    0.8578050000000002,
    0.8782810000000001,
    0.8874309999999999,
    0.8949189999999999,
    0.9058740000000001,
    0.910816,
    0.91232,
    0.9228829999999999,
    0.925807,
    0.9254700000000001,
    0.9322469999999999,
    0.93186,
    0.9359569999999999,
    0.9327495,
    0.9341550000000001,
    0.932254,
    0.935063,
    0.9339679999999999,
    0.9352115,
    0.935036,
    0.9319865,
    0.930997,
    0.9268995,
    0.9262865,
    0.9265455000000001,
    0.9199934999999999,
    0.919614,
    0.9145384999999999,
    0.9161775,
    0.9134969999999999,
    0.9094895000000001,
    0.9101015,
    0.9100930000000002,
    0.904062,
    0.9085645,
    0.9039079999999999,
    0.9013275000000001,
    0.902245,
    0.9020645,
    0.898707,
    0.8962109999999999,
    0.891911,
    0.896126,
    0.8924469999999999,
    0.8947739999999998,
    0.890651,
]

# smart cnn with size of 16 baseline model

num_epochs = len(Accuracies)
epochs = list(range(1, num_epochs + 1))
plt.plot(epochs, Accuracies, label="Accuracy")
plt.plot(epochs, F1s, label="F1 Score")
plt.plot(epochs, AUCs, label="AUC score")
plt.xlabel("Epochs")
plt.ylabel("Score")
plt.title('"smart" CNN performance')

plt.legend()
plt.grid()
plt.show()

# %%
accuracies = [
    0.8185,
    0.8205,
    0.7785,
    0.6915,
    0.773,
    0.735,
    0.711,
    0.714,
    0.6555,
    0.6635,
    0.671,
    0.696,
    0.709,
    0.6965,
    0.705,
    0.708,
    0.7105,
    0.712,
    0.706,
    0.618,
]
F1s = [
    0.8184236925567969,
    0.8204999551249886,
    0.7747220321598284,
    0.6757341114313187,
    0.7724536612406389,
    0.734253518132434,
    0.7109164548554533,
    0.712063917783174,
    0.6550894702419555,
    0.6594163164887795,
    0.6676767676767676,
    0.6917807871959251,
    0.7063498070082495,
    0.6867412862340857,
    0.7029036884255306,
    0.697064010789501,
    0.7009723048192263,
    0.7027937388547653,
    0.6953465743587512,
    0.6136590733481397,
]
aucs = [
    0.8185,
    0.8204999999999999,
    0.7785,
    0.6915,
    0.773,
    0.7349999999999999,
    0.711,
    0.7140000000000001,
    0.6555,
    0.6635000000000001,
    0.6709999999999999,
    0.696,
    0.709,
    0.6965,
    0.7050000000000001,
    0.7080000000000001,
    0.7105,
    0.712,
    0.7060000000000001,
    0.618,
]

# dumb cnn with size of 6000
num_epochs = len(accuracies)
epochs = list(range(1, num_epochs + 1))

plt.plot(epochs, accuracies, label="Accuracy")
plt.plot(epochs, F1s, label="F1 Score")
plt.plot(epochs, aucs, label="AUC score")
plt.xlabel("Epochs")
plt.ylabel("Score")
plt.xticks(epochs)
plt.title('"dumb" CNN performance')
plt.legend()
plt.grid()
plt.show()

# %%
# With6000 real images, 2000 synthetic images
accuracy = [
    0.835,
    0.833,
    0.811,
    0.7365,
    0.7285,
    0.7515,
    0.7055,
    0.7685,
    0.757,
    0.6985,
    0.7575,
    0.6965,
    0.7325,
    0.699,
    0.7395,
    0.6925,
    0.708,
    0.714,
    0.719,
    0.7265,
]
F1s = [
    0.8349676536601173,
    0.8312442653365616,
    0.8109931957550471,
    0.7353295611518036,
    0.7182761718453092,
    0.7480211165402336,
    0.7042696879693747,
    0.7684369569615328,
    0.7568927897202666,
    0.6928608483916835,
    0.7570611917776483,
    0.6958423350890462,
    0.73167348725913,
    0.6932424678796328,
    0.738161415697399,
    0.6905933589260419,
    0.7074335914330143,
    0.7137592715473713,
    0.7189525029730024,
    0.7264999316249828,
]
acus = [
    0.835,
    0.833,
    0.811,
    0.7364999999999999,
    0.7285000000000001,
    0.7515000000000001,
    0.7055,
    0.7685000000000001,
    0.757,
    0.6984999999999999,
    0.7575,
    0.6964999999999999,
    0.7325,
    0.6990000000000001,
    0.7394999999999999,
    0.6925,
    0.708,
    0.7140000000000001,
    0.719,
    0.7264999999999999,
]

# dumb cnn with size of 6000
num_epochs = len(accuracy)
epochs = list(range(1, num_epochs + 1))

plt.plot(epochs, accuracy, label="Accuracy")
plt.plot(epochs, F1s, label="F1 Score")
plt.plot(epochs, aucs, label="AUC score")
plt.xlabel("Epochs")
plt.ylabel("Score")
plt.xticks(epochs)
plt.title('"dumb" CNN performance')
plt.legend()
plt.grid()
plt.show()

# %%
# With6000 real images, 0 synthetic images
accuracy_6_0 = [
    0.8185,
    0.8205,
    0.7785,
    0.6915,
    0.773,
    0.735,
    0.711,
    0.714,
    0.6555,
    0.6635,
    0.671,
    0.696,
    0.709,
    0.6965,
    0.705,
    0.708,
    0.7105,
    0.712,
    0.706,
    0.618,
]
F1s_6_0 = [
    0.8184236925567969,
    0.8204999551249886,
    0.7747220321598284,
    0.6757341114313187,
    0.7724536612406389,
    0.734253518132434,
    0.7109164548554533,
    0.712063917783174,
    0.6550894702419555,
    0.6594163164887795,
    0.6676767676767676,
    0.6917807871959251,
    0.7063498070082495,
    0.6867412862340857,
    0.7029036884255306,
    0.697064010789501,
    0.7009723048192263,
    0.7027937388547653,
    0.6953465743587512,
    0.6136590733481397,
]
aucs_6_0 = [
    0.8185,
    0.6215,
    0.6105,
    0.616,
    0.6715,
    0.6745,
    0.6775,
    0.6775,
    0.6775,
    0.6795,
]
F1s_2_6 = [
    0.5915215652668252,
    0.7011143906218854,
    0.690185083838566,
    0.6535857872082292,
    0.6643077754962767,
    0.6182967849946633,
    0.6334176472744603,
    0.5719716038955153,
    0.5935450025896771,
    0.6056004732794321,
    0.6191505701263794,
    0.6197675659724621,
    0.5907838642768235,
    0.6084345642152019,
    0.6698119963784859,
    0.6734202456873036,
    0.6757959022109966,
    0.6759796153501265,
    0.6759796153501265,
    0.6785451988769644,
]
aucs_2_6 = [
    0.6375,
    0.7095,
    0.696,
    0.6645,
    0.6659999999999999,
    0.627,
    0.64,
    0.5785,
    0.6035,
    0.608,
    0.635,
    0.6215,
    0.6105,
    0.616,
    0.6715,
    0.6745,
    0.6775,
    0.6775,
    0.6775,
    0.6795,
]

num_epochs = len(accuracy_6_0)
epochs = list(range(1, num_epochs + 1))

fig, axes = plt.subplots(2, 2, figsize=(12, 10))


axes[0, 0].plot(epochs, accuracy_6_0, label="Accuracy")
axes[0, 0].plot(epochs, F1s_6_0, label="F1 Score")
axes[0, 0].plot(epochs, aucs_6_0, label="AUC score")
axes[0, 0].set_xlabel("Epochs")
axes[0, 0].set_ylabel("Score")
axes[0, 0].set_xticks(epochs)
axes[0, 0].set_title("baseline CNN with 6000 training images")
axes[0, 0].legend()
axes[0, 0].grid()

axes[0, 1].plot(epochs, accuracy_6_2, label="Accuracy")
axes[0, 1].plot(epochs, F1s_6_2, label="F1 Score")
axes[0, 1].plot(epochs, aucs_6_2, label="AUC score")
axes[0, 1].set_xlabel("Epochs")
axes[0, 1].set_ylabel("Score")
axes[0, 1].set_xticks(epochs)
axes[0, 1].set_title("Augmented CNN with 6000 training and 2000 synthetic images")
axes[0, 1].legend()
axes[0, 1].grid()

axes[1, 0].plot(epochs, accuracy_6_0, label="Accuracy")
axes[1, 0].plot(epochs, F1s_6_0, label="F1 Score")
axes[1, 0].plot(epochs, aucs_6_0, label="AUC score")
axes[1, 0].set_xlabel("Epochs")
axes[1, 0].set_ylabel("Score")
axes[1, 0].set_xticks(epochs)
axes[1, 0].set_title("Augmented CNN with 6000 training and 6000 synthetic images")
axes[1, 0].legend()
axes[1, 0].grid()

axes[1, 1].plot(epochs, accuracy_6_0, label="Accuracy")
axes[1, 1].plot(epochs, F1s_6_0, label="F1 Score")
axes[1, 1].plot(epochs, aucs_6_0, label="AUC score")
axes[1, 1].set_xlabel("Epochs")
axes[1, 1].set_ylabel("Score")
axes[1, 1].set_xticks(epochs)
axes[1, 1].set_title("Augmented CNN with 2000 training and 6000 synthetic images")
axes[1, 1].legend()
axes[1, 1].grid()

plt.suptitle('"dumb" CNN performances')
plt.tight_layout()
plt.show()
